# %%
runnning = 10

for i in range (runnning):
    print("Round is ",i)    
Round is  0
Round is  1
Round is  2
Round is  3
Round is  4
Round is  5
Round is  6
Round is  7
Round is  8
Round is  9
check = True

while(check):
    print("Check")
    check = False
Check
running_str = input("จำนวนรอบที่ต้องการวิ่ง : ")
runnning_int = int(running_str)

for i in range(runnning_int):
    print("Round is : " , i+1)
Round is :  1
state = input("สั่งให้เริ่มวิ่ง ด้วยคำสั่ง 1")
state_running = True
if (state == '1'):
    state_running = True
else:
    state_running = false
i = 1
while (state):
    print("Round :" , i)
    i = i+1
    interup = input("ต้องการหยุดหรือไม่ 1 stop or 0 run")
    if(interup == '1'):
        state = True
    elif(interup == '0'):
        state = False
Round : 1
Round : 2
Round : 3
Round : 4
Round : 5
Round : 6
Round : 7
Round : 8
Round : 9
Round : 10
Round : 11
Round : 12
Round : 13
Round : 14
Round : 15
Round : 16
Round : 17
Round : 18
Round : 19
Q = "Press Q =Exit"
M = "Press M =Main"
S = "Press S =Start In program"

State = True

while State:
    print(Q)
    print(M)
    print(S)
    
    inp = input("Menu Selected : ")

    if inp == 'Q':
        State = False

    elif inp == 'M':
        print("Home Menu :")

    elif inp == 'S':
        print("Start Now ex. 10 รอบ")
        
        running_str = input("จำนวนรอบที่ต้องการวิ่ง : ")
        running_int = int(running_str)

        for i in range(running_int):
            print("Round is : ", i + 1)


    else:
        print("Home menu ")
Press Q =Exit
Press M =Main
Press S =Start In program
Start Now ex. 10 รอบ
Round is :  1
Round is :  2
Round is :  3
Round is :  4
Round is :  5
Round is :  6
Round is :  7
Round is :  8
Round is :  9
Round is :  10
Press Q =Exit
Press M =Main
Press S =Start In program
